# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *
from datetime import datetime

# %%
# cur.close()
# conn.close()

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
conn.set_session(autocommit=False)

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %%
def execute_query(*args, do_commit=True, print_result=False, head=1, **kwargs):
    try:
        cur.execute(*args, **kwargs)
    except psycopg2.Error as e:
        print(f"Error with query \n {str(args)}")
        print(e)
    if do_commit:
        conn.commit()
    if do_commit and print_result:
        for i in range(head):
            print(cur.fetchone(), "\n")

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files("./data/song_data")
print(len(song_files))
# Out:
# 60

# %%
filepath = song_files[0]
print(filepath)
# Out:
# /home/hieunguyen/Documents/Data_Modeling/project/song_data/A/A/A/TRAAARJ128F9320760.json

# %%
df = pd.read_json(filepath, lines=True)
df
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR8ZCNI1187B9A069B              NaN               NaN
#
#   artist_location       artist_name             song_id       title  \
# 0                  Planet P Project  SOIAZJW12AB01853F1  Pink World
#
#     duration  year
# 0  269.81832  1984

# %%
records = pd.DataFrame()
for filepath in song_files:
    df = pd.read_json(filepath, lines=True)
    records = records.append(df, ignore_index=True)
records
# Out:
#     num_songs           artist_id  artist_latitude  artist_longitude  \
# 0           1  AR8ZCNI1187B9A069B              NaN               NaN
# 1           1  ARNTLGG11E2835DDB9              NaN               NaN
# 2           1  ARD7TVE1187B99BFB1              NaN               NaN
# 3           1  ARKRRTF1187B9984DA              NaN               NaN
# 4           1  ARKFYS91187B98E58F              NaN               NaN
# 5           1  AR10USD1187B99F3F1              NaN               NaN
# 6           1  ARMJAGH1187FB546F3         35.14968         -90.04892
# 7           1  ARD0S291187B9B7BF5              NaN               NaN
# 8           1  ARXR32B1187FB57099              NaN               NaN
# 9           1  AR7G5I41187FB4CE6C              NaN               NaN
# 10          1  ARC43071187B990240              NaN               NaN
# 11          1  ARYKCQI1187FB3B18F              NaN               NaN
# 12          1  ARNPAGP1241B9C7FD4              NaN               NaN
# 13          1  ARQGYP71187FB44566         34.31109         -94.02978
# 14          1  ARHHO3O1187B989413              NaN               NaN
# 15          1  ARIK43K1187B9AE54C              NaN               NaN
# 16          1  ARL7K851187B99ACD2              NaN               NaN
# 17          1  ARD842G1187B997376         43.64856         -79.38533
# 18          1  AR1ZHYZ1187FB3C717              NaN               NaN
# 19          1  ARIG6O41187B988BDD         37.16793         -95.84502
# 20          1  AR47JEX1187B995D81         37.83721         -94.35868
# 21          1  ARMAC4T1187FB3FA4C         40.82624         -74.47995
# 22          1  AROUOZZ1187B9ABE51         40.79195         -73.94512
# 23          1  ARB29H41187B98F0EF         41.88415         -87.63241
# 24          1  ARDNS031187B9924F0         32.67828         -83.22295
# 25          1  ARNTLGG11E2835DDB9              NaN               NaN
# 26          1  ARH4Z031187B9A71F2         40.73197         -74.17418
# 27          1  AR5KOSW1187FB35FF4         49.80388          15.47491
# 28          1  AR1Y2PT1187FB5B9CE         27.94017         -82.32547
# 29          1  ARGIWFO1187B9B55B7              NaN               NaN
# 30          1  ARD7TVE1187B99BFB1              NaN               NaN
# 31          1  ARKULSX1187FB45F84         39.49974        -111.54732
# 32          1  ARMBR4Y1187B9990EB         37.77916        -122.42005
# 33          1  ARI2JSK1187FB496EF         51.50632          -0.12714
# 34          1  ARPBNLO1187FB3D52F         40.71455         -74.00712
# 35          1  ARQ9BO41187FB5CF1F         40.99471         -77.60454
# 36          1  AROGWRA122988FEE45              NaN               NaN
# 37          1  AR9AWNF1187B9AB0B4              NaN               NaN
# 38          1  AREDBBQ1187B98AFF5              NaN               NaN
# 39          1  AR3JMC51187B9AE49D         28.53823         -81.37739
# 40          1  AREDL271187FB40F44              NaN               NaN
# 41          1  ARAGB2O1187FB3A161              NaN               NaN
# 42          1  ARGCY1Y1187B9A4FA5         36.16778         -86.77836
# 43          1  AR62SOJ1187FB47BB5              NaN               NaN
# 44          1  ARBEBBY1187B9B43DB              NaN               NaN
# 45          1  ARNNKDK1187B98BBD5         45.80726          15.96760
# 46          1  ARBGXIG122988F409D         37.77916        -122.42005
# 47          1  AR36F9J1187FB406F1         56.27609           9.51695
# 48          1  ARDR4AC1187FB371A1              NaN               NaN
# 49          1  AR7SMBG1187B9B9066              NaN               NaN
# 50          1  AR558FS1187FB45658              NaN               NaN
# 51          1  AR0IAWL1187B9A96D0          8.41770         -80.11278
# 52          1  ARNF6401187FB57032         40.79086         -73.96644
# 53          1  ARPFHN61187FB575F6         41.88415         -87.63241
# 54          1  ARLTWXK1187FB5A3F8         32.74863         -97.32925
# 55          1  AR8IEZO1187B99055E              NaN               NaN
# 56          1  ARJIE2Y1187B994AB7              NaN               NaN
# 57          1  AR051KA1187B98B2FF              NaN               NaN
# 58          1  ARULZCI1241B9C8611              NaN               NaN
# 59          1  ARVBRGZ1187FB4675A              NaN               NaN
#
#                   artist_location  \
# 0
# 1
# 2                 California - LA
# 3
# 4
# 5     Burlington, Ontario, Canada
# 6                     Memphis, TN
# 7                            Ohio
# 8
# 9                 London, England
# 10                     Wisner, LA
# 11
# 12
# 13                    Mineola, AR
# 14
# 15              Beverly Hills, CA
# 16
# 17       Toronto, Ontario, Canada
# 18
# 19                  United States
# 20                     Nevada, MO
# 21              Morris Plains, NJ
# 22  New York, NY [Spanish Harlem]
# 23                        Chicago
# 24                        Georgia
# 25
# 26                     Newark, NJ
# 27                      Dubai UAE
# 28                        Brandon
# 29
# 30                California - LA
# 31                           Utah
# 32                California - SF
# 33                London, England
# 34                   New York, NY
# 35                   Pennsylvania
# 36
# 37        Seattle, Washington USA
# 38
# 39                    Orlando, FL
# 40
# 41
# 42                 Nashville, TN.
# 43
# 44                Gainesville, FL
# 45                 Zagreb Croatia
# 46                California - SF
# 47                        Denmark
# 48
# 49
# 50
# 51                         Panama
# 52       New York, NY [Manhattan]
# 53                    Chicago, IL
# 54                 Fort Worth, TX
# 55
# 56
# 57
# 58
# 59
#
#                                           artist_name             song_id  \
# 0                                    Planet P Project  SOIAZJW12AB01853F1
# 1                                                 Clp  SOUDSGM12AC9618304
# 2                                              Casual  SOMZWCG12A8C13C480
# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = list(records[["song_id", "title", "artist_id", "year", "duration"]].values[0])
song_data
# Out:
# ['SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 269.81832]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
execute_query(song_table_insert, song_data)

# %%
execute_query("Select * from songs")
cur.fetchall()
# Out:
# [('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 269.81832)]

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = list(records[["artist_id","artist_name", "artist_location", "artist_latitude", "artist_longitude"]].values[0])
artist_data
# Out:
# ['AR8ZCNI1187B9A069B', 'Planet P Project', '', nan, nan]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
execute_query(artist_table_insert, artist_data)

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files(".data/log_data")

# %%
filepath = log_files[0]
filepath
# Out:
# '/home/hieunguyen/Documents/Data_Modeling/project/log_data/2018-11-03-events.json'

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#           artist        auth firstName gender  itemInSession  lastName  \
# 0           None  Logged Out      None   None              0      None
# 1           None   Logged In   Celeste      F              1  Williams
# 2           Mynt   Logged In   Celeste      F              2  Williams
# 3   Taylor Swift   Logged In   Celeste      F              3  Williams
# 4  Amy Winehouse   Logged In   Celeste      F              4  Williams
#
#       length level           location method      page  registration  \
# 0        NaN  free               None    PUT     Login           NaN
# 1        NaN  free  Klamath Falls, OR    GET      Home  1.541078e+12
# 2  166.94812  free  Klamath Falls, OR    PUT  NextSong  1.541078e+12
# 3  230.47791  free  Klamath Falls, OR    PUT  NextSong  1.541078e+12
# 4  229.85098  free  Klamath Falls, OR    PUT  NextSong  1.541078e+12
#
#    sessionId                song  status             ts  \
# 0         52                None     307  1541207073796
# 1         52                None     200  1541207123796
# 2         52        Playa Haters     200  1541207150796
# 3         52  You Belong With Me     200  1541207316796
# 4         52             Valerie     200  1541207546796
#
#                                            userAgent userId
# 0                                               None
# 1  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 4  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df[df.page == "NextSong"]
df.head()
# Out:
#             artist       auth firstName gender  itemInSession  lastName  \
# 2             Mynt  Logged In   Celeste      F              2  Williams
# 3     Taylor Swift  Logged In   Celeste      F              3  Williams
# 4    Amy Winehouse  Logged In   Celeste      F              4  Williams
# 5  Jimmy Eat World  Logged In   Celeste      F              5  Williams
# 7    Maldita Nerea  Logged In  Anabelle      F              0   Simpson
#
#       length level                                     location method  \
# 2  166.94812  free                            Klamath Falls, OR    PUT
# 3  230.47791  free                            Klamath Falls, OR    PUT
# 4  229.85098  free                            Klamath Falls, OR    PUT
# 5  285.83138  free                            Klamath Falls, OR    PUT
# 7  241.16200  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD    PUT
#
#        page  registration  sessionId                song  status  \
# 2  NextSong  1.541078e+12         52        Playa Haters     200
# 3  NextSong  1.541078e+12         52  You Belong With Me     200
# 4  NextSong  1.541078e+12         52             Valerie     200
# 5  NextSong  1.541078e+12         52               Dizzy     200
# 7  NextSong  1.541044e+12        158          Supelicula     200
#
#               ts                                          userAgent userId
# 2  1541207150796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 3  1541207316796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 4  1541207546796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 5  1541207775796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 7  1541254670796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     69

# %%
t = df["ts"].apply(lambda t : datetime.fromtimestamp(t / 1000))
t.head()
# Out:
# 2   2018-11-03 08:05:50.796
# 3   2018-11-03 08:08:36.796
# 4   2018-11-03 08:12:26.796
# 5   2018-11-03 08:16:15.796
# 7   2018-11-03 21:17:50.796
# Name: ts, dtype: datetime64[ns]

# %%
time_data = (df["ts"], t.dt.hour, t.dt.day, t.dt.isocalendar().week, t.dt.month, t.dt.year, t.dt.weekday)
column_labels = ("timestamp", "hour", "day", "week_of_year", "month", "year", "weekday")

# %%
time_df = pd.DataFrame({column_labels[i]: time_data[i] for i in range(len(time_data))})
time_df.head()
# Out:
#        timestamp  hour  day  week_of_year  month  year  weekday
# 2  1541207150796     8    3            44     11  2018        5
# 3  1541207316796     8    3            44     11  2018        5
# 4  1541207546796     8    3            44     11  2018        5
# 5  1541207775796     8    3            44     11  2018        5
# 7  1541254670796    21    3            44     11  2018        5

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    execute_query(time_table_insert, list(row))

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[["userId", "firstName", "lastName", "gender", "level"]] 
user_df.head()
# Out:
#   userId firstName  lastName gender level
# 2     53   Celeste  Williams      F  free
# 3     53   Celeste  Williams      F  free
# 4     53   Celeste  Williams      F  free
# 5     53   Celeste  Williams      F  free
# 7     69  Anabelle   Simpson      F  free

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    execute_query(user_table_insert, row)

# %%
execute_query("SELECT * FROM users", print_result=True, head = 5)
# Out:
# ('53', 'Celeste', 'Williams', 'F', 'free')
# ('53', 'Celeste', 'Williams', 'F', 'free')
# ('53', 'Celeste', 'Williams', 'F', 'free')
# ('53', 'Celeste', 'Williams', 'F', 'free')
# ('69', 'Anabelle', 'Simpson', 'F', 'free')

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
df[df["song"] == "Pink World"]
# Out:
# Empty DataFrame
# Columns: [artist, auth, firstName, gender, itemInSession, lastName, length, level, location, method, page, registration, sessionId, song, status, ts, userAgent, userId]
# Index: []

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = (row.itemInSession, row.registration, row.userId, row.level, songid,
                     artistid, row.sessionId, row.location, row.userAgent)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

# %%
cur.execute("SELECT * FROM songplays where")
conn.commit()
x = cur.fetchall()

# %%
y=pd.DataFrame(x, columns=['a','b','c','d','a1','b1','c1','d1','a2'])
y[y['c1'] > 53]
# y['a1'][0] != None
# Out:
#      a              b    c     d    a1    b1   c1  \
# 4    0  1541044398796   69  free  None  None  158
# 5    0  1540823606796   62  free  None  None  168
# 6    0  1541033612796  101  free  None  None  185
# 7    0  1540809153796   95  paid  None  None  152
# 8    1  1540809153796   95  paid  None  None  152
# ..  ..            ...  ...   ...   ...   ...  ...
# 93  63  1540809153796   95  paid  None  None  152
# 94   0  1540880381796   63  free  None  None  135
# 95   1  1540940782796   49  free  None  None  195
# 96   2  1540940782796   49  free  None  None  195
# 97   3  1540940782796   49  free  None  None  195
#
#                                              d1  \
# 4   Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 5          Houston-The Woodlands-Sugar Land, TX
# 6                      New Orleans-Metairie, LA
# 7                             Winston-Salem, NC
# 8                             Winston-Salem, NC
# ..                                          ...
# 93                            Winston-Salem, NC
# 94                               Santa Rosa, CA
# 95            San Francisco-Oakland-Hayward, CA
# 96            San Francisco-Oakland-Hayward, CA
# 97            San Francisco-Oakland-Hayward, CA
#
#                                                    a2
# 4   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 5   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10)...
# 6   "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 7   "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 8   "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# ..                                                ...
# 93  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 94  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 95  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 96  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 97  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
#
# [94 rows x 9 columns]

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
cur.close()
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
